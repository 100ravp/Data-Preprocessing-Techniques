# %%
#importing libraires
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import pandas as pd
pd.options.mode.chained_assignment = None 

import scipy.stats as stats

# %%
#loading the data
data = pd.read_csv("Clean_data")

data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  Missing      Reg
# 1   2          20       RL         80.0     9600   Pave  Missing      Reg
# 2   3          60       RL         68.0    11250   Pave  Missing      IR1
# 3   4          70       RL         60.0     9550   Pave  Missing      IR1
# 4   5          60       RL         84.0    14260   Pave  Missing      IR1
#
#   LandContour Utilities  ... MiscFeature MiscVal MoSold YrSold SaleType  \
# 0         Lvl    AllPub  ...     Missing       0      2   2008       WD
# 1         Lvl    AllPub  ...     Missing       0      5   2007       WD
# 2         Lvl    AllPub  ...     Missing       0      9   2008       WD
# 3         Lvl    AllPub  ...     Missing       0      2   2006       WD
# 4         Lvl    AllPub  ...     Missing       0     12   2008       WD
#
#   SaleCondition SalePrice  LotFrontage_na  MasVnrArea_na  GarageYrBlt_na
# ...

# %%
#subsetting the data
data = data[["LotFrontage","LotArea","GrLivArea","SalePrice"]]

# %%
#splitting the data
X_train, X_test, y_train, y_test = train_test_split(data, 
    data['SalePrice'],  
    test_size=0.3,  
    random_state=42)

# %%
#function for plotting

def diag_plots(df, variable):
    
    """
    function to plot a histogram and a Q-Q plot
    side by side, for a certain variable
    """
    
    
    plt.figure(figsize=(15,5))
    plt.subplot(1, 2, 1)
    df[variable].hist(bins=50)

    plt.subplot(1, 2, 2)
    stats.probplot(df[variable], dist="norm", plot=plt)

    plt.show()

# %%
#creating list of continious variable
num_var = ["LotFrontage","LotArea","GrLivArea"]

# %%
#applying plotting function
for var in num_var:
    diag_plots(X_train,var)

# %%
#log transformation
for var in num_var:
    X_train[var+"_log"] = np.log(X_train[var])

# %%
#storing transformed variable
transformed = ["LotFrontage_log","LotArea_log","GrLivArea_log"]

# %%
#applying the plotting function
for var in transformed:
    diag_plots(X_train,var)
